# %%
# pip install pandas
# pip install openpyxl

# %%
import pandas as pd

# %%
all_sheets = pd.read_excel('../Raw_Data/regionalgrossdomesticproductgdpbyallinternationalterritoriallevelitlregions.xlsx', sheet_name=None)
print(all_sheets.keys())
# Out:
# dict_keys(['Notice', 'Information', 'Contents', 'Notes', 'Table 1', 'Table 2', 'Table 3', 'Table 4', 'Table 5', 'Table 6', 'Table 7', 'Table 8', 'Table 9', 'Table 10', 'Table 11', 'Table 12', 'Table 13'])

# %%
for i in all_sheets['Contents']['Unnamed: 1'].head(20):
    print(i)
# Out:
# Table name
# Table 1: Gross value added (Balanced) at current basic prices, pounds million
# Table 2: Value Added Tax (VAT) on products, pounds million
# Table 3: Other taxes on products, pounds million
# Table 4: Subsidies on products, pounds million
# Table 5: Gross domestic product (GDP) at current market prices, pounds million
# Table 6: Total resident population numbers, persons [notes 4, 5]
# Table 7: Gross domestic product (GDP) per head at current market prices, pounds [notes 5, 6]
# Table 8: Gross domestic product (GDP) implied deflators, 2022 equals 100 [note 2]
# Table 9: Gross domestic product (GDP) chained volume measures (CVM) index, 2022 equals 100 [note 1]
# Table 10: Gross domestic product (GDP) chained volume measures (CVM) in 2022 money value, pounds million [notes 1, 3]
# Table 11: Gross domestic product (GDP) chained volume measures (CVM) in 2022 money value, per head, pounds [notes 1, 5, 6]
# ...

# %%
gdp_cp_capita = all_sheets['Table 7']
gdp_cp_capita.columns = gdp_cp_capita.iloc[0]
gdp_cp_capita = gdp_cp_capita[1:]
gdp_cp_capita = gdp_cp_capita[gdp_cp_capita['ITL'] == 'ITL1']
gdp_cp_capita
# Out:
# 0     ITL ITL code               Region name   1998   1999   2000   2001  \
# 3    ITL1      TLC                North East  12744  13071  13525  14139
# 13   ITL1      TLD                North West  14616  15398  15815  16719
# 39   ITL1      TLE  Yorkshire and The Humber  14211  14729  15241  15891
# 57   ITL1      TLF             East Midlands  14718  15126  15644  16192
# 72   ITL1      TLG             West Midlands  14967  15492  15979  16511
# 90   ITL1      TLH                      East  16270  16867  17651  18463
# 116  ITL1      TLI                    London  27715  28902  30800  31340
# 143  ITL1      TLJ                South East  19033  19834  20726  21422
# 170  ITL1      TLK                South West  15403  16094  16727  17489
# 189  ITL1      TLL                     Wales  12790  13131  13709  14135
# 205  ITL1      TLM                  Scotland  15406  15758  16455  17370
# 230  ITL1      TLN          Northern Ireland  13282  14058  15086  15692
#
# ...

# %%
gdp_cp_capita.to_csv('itl1_gdp_cp_capita_1998_2023.csv')

# %%
gdp_cvm_capita = all_sheets['Table 11']
gdp_cvm_capita.columns = gdp_cvm_capita.iloc[0]
gdp_cvm_capita = gdp_cvm_capita[1:]
gdp_cvm_capita = gdp_cvm_capita[gdp_cvm_capita['ITL'] == 'ITL1']
gdp_cvm_capita
# Out:
# 0     ITL ITL code               Region name   1998   1999   2000   2001  \
# 3    ITL1      TLC                North East  19454  19848  20409  21343
# 13   ITL1      TLD                North West  23555  24461  24964  25998
# 39   ITL1      TLE  Yorkshire and The Humber  23300  23935  24609  25406
# 57   ITL1      TLF             East Midlands  24712  25176  25832  26430
# 72   ITL1      TLG             West Midlands  24535  25215  25880  26551
# 90   ITL1      TLH                      East  25739  26430  27642  28440
# 116  ITL1      TLI                    London  45281  46355  49320  49228
# 143  ITL1      TLJ                South East  29143  30015  31432  31928
# 170  ITL1      TLK                South West  26474  27185  27947  28786
# 189  ITL1      TLL                     Wales  21033  21424  22222  22818
# 205  ITL1      TLM                  Scotland  25282  25675  26601  27648
# 230  ITL1      TLN          Northern Ireland  23665  24470  25961  26647
#
# ...

# %%
gdp_cvm_capita.to_csv('itl1_gdp_cvm_capita_1998_2023.csv')
